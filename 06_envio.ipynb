# %%
pip install resend --quiet

# %%
# %restart_python

# %%
import resend
import os
from dotenv import load_dotenv

# %%
load_dotenv()

# %%
resend.api_key = os.getenv("RESEND_API_KEY")

# %%
html = dbutils.jobs.taskValues.get(
    taskKey = 'agente_email',
    key = 'html'
)

# %%
params = {
    "from": 'BRENT Analytics <onboarding@resend.dev>',
    "to": os.getenv("EMAIL_DESTINO"),
    "subject": "Informe estratégico BRENT",
    'html': html
}

# %%
respuesta = resend.Emails.send(params)
print(f'Email enviado con exito', respuesta)
